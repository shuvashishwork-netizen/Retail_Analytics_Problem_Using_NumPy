# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvashishwork-netizen/Retail_Analytics_Problem_Using_NumPy/blob/main/notebooks/convert2md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create a sample dataset of employees
employees = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank', 'Grace', 'Henry'],
    'department': ['Sales', 'IT', 'Sales', 'HR', 'IT', 'Sales', 'HR', 'IT'],
    'salary': [45000, 55000, 48000, 42000, 62000, 51000, 44000, 58000],
    'years_experience': [3, 7, 4, 2, 9, 5, 3, 6],
    'city': ['London', 'Manchester', 'London', 'Birmingham', 'London', 'Manchester', 'Birmingham', 'London']
})

employees

# %%
employees[((employees['city'] == 'London') & (employees['salary'] > 50000))| ((employees['city'] == 'Manchester') & (employees['years_experience'] > 5))]
# Out:
#     name department  salary  years_experience        city
# 1    Bob         IT   55000                 7  Manchester
# 4    Eve         IT   62000                 9      London
# 7  Henry         IT   58000                 6      London

# %% [markdown]
# isin method
